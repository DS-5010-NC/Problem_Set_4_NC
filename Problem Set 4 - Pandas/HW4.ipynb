# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np 

def prob1(): 
    
    
    string_list = ["String1", "String2", "String3", "string4", "String5"]
    pd.Series(string_list)
    print(pd.Series(string_list))
    print() #I am only inlcuding print statements visually for spaces in terminal output, not apart of the 3 lines of code for the problem 
    
    arr = np.random.randint(1, 101,(5))
    pd.Series(arr)
    print(pd.Series(arr))
    print()
    
    data_dict = {"String1": 10,"String2": 25, "String3": 15, "String4": 30, "String5": 20}
    pd.Series(data_dict)
    print(pd.Series(data_dict))
    
    
    df = pd.DataFrame = ({
        "strings": string_list, 
        "random number": arr,
        "values":[data_dict[s] for s in string_list]
    })

    print(df)
prob1()
# Out:
# 0    String1
# 1    String2
# 2    String3
# 3    string4
# 4    String5
# dtype: object
#
# 0     30
# 1    100
# 2     15
# 3     49
# 4     42
# dtype: int64
#
# String1    10
# String2    25
# String3    15
# String4    30
# String5    20
# dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 29
#      22     df = pd.DataFrame = ({
#      23         "strings": string_list,
#      24         "random number": arr,
#      25         "values":[data_dict[s] for s in string_list]
#      26     })
#      28     print(df)
# ---> 29 prob1()
#
# Cell In[8], line 25, in prob1()
#      18 pd.Series(data_dict)
#      19 print(pd.Series(data_dict))
#      22 df = pd.DataFrame = ({
#      23     "strings": string_list,
#      24     "random number": arr,
# ---> 25     "values":[data_dict[s] for s in string_list]
#      26 })
#      28 print(df)
#
# KeyError: 'string4'
